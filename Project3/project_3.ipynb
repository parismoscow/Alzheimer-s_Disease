# %%
import os

import pandas as pd
import numpy as np

# %%
file_one = "TADPOLE_D1_D2.csv"

# %%
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")
file_one_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (471,473,474,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,569,570,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,599,601,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,621,624,625,626,627,628,629,630,631,632,633,634,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,663,664,665,666,667,668,669,670,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,719,720,721,722,723,7
# ...

# %%
selected_file_one = file_one_df.loc[:, ["DX","ADAS13", "Ventricles", "CDRSB", "ADAS11", "MMSE",  "RAVLT_immediate", "Hippocampus", "WholeBrain", "Entorhinal", "MidTemp", "FDG", "AV45", "ABETA_UPENNBIOMK9_04_19_17", "TAU_UPENNBIOMK9_04_19_17", "PTAU_UPENNBIOMK9_04_19_17", "APOE4", "AGE"]]
selected_file_one.head()
# Out:
#          DX  ADAS13  Ventricles  CDRSB  ADAS11  MMSE  RAVLT_immediate  \
# 0        NL   18.67    118233.0    0.0   10.67  28.0             44.0
# 1  Dementia   31.00     84599.0    4.5   22.00  20.0             22.0
# 2  Dementia   30.00     88580.0    6.0   19.00  24.0             19.0
# 3  Dementia   35.00     90099.0    3.5   24.00  17.0             31.0
# 4  Dementia   37.67     97420.0    8.0   25.67  19.0             23.0
#
#    Hippocampus  WholeBrain  Entorhinal  MidTemp      FDG  AV45  \
# 0       8336.0   1229740.0      4177.0  27936.0  1.36926   NaN
# 1       5319.0   1129830.0      1791.0  18422.0  1.09079   NaN
# 2       5446.0   1100060.0      2427.0  16972.0  1.06360   NaN
# 3       5157.0   1095640.0      1596.0  17330.0  1.10384   NaN
# 4       5139.0   1088560.0      1175.0  16398.0  1.03871   NaN
#
#   ABETA_UPENNBIOMK9_04_19_17 TAU_UPENNBIOMK9_04_19_17  \
# 0
# 1                      741.5                    239.7
# 2
# ...

# %%
selected_file_one.to_csv("measures.csv", index=False, header=True)
